# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        s = s.rstrip()     
        last_word = s.split()[-1]
        return len(last_word)
